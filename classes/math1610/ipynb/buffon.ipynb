# %% [markdown]
# # Buffon's Needle and Bertrand's Paradox

# %%
# If you don't have the package Graphics2D installed, 
# Run the following command to get it
# Pkg.clone("git://github.com/sswatson/Graphics2D.jl.git")

# %%
using Graphics2D

# %%
using Gadfly

# %%
# n is the size of the box in which we're tossing needles
n = 10
# Out:
# 10

# %%
# generates a random triple of real numbers representing a needle 
# of the form (xposition,yposition,angle)
function needle(n)
    return (n*rand(), n*rand(), π*rand())
end

function drawneedle(t)
    return Line([t[1]-0.5*cos(t[3]) t[2]-0.5*sin(t[3]); t[1]+0.5*cos(t[3]) t[2]+0.5*sin(t[3])];
    color =  hitline(t) ? green*0.5 : black )
end

# returns true or flase depending on whether the needle is hitting a line
function hitline(t)
    return min(t[2]-floor(t[2]),1-(t[2]-floor(t[2]))) < sin(t[3])/2
end
# Out:
# hitline (generic function with 1 method)

# %%
numtrials = 1000
showgraphics([[drawneedle(needle(n)) for _=1:numtrials],[Line([0 k; n k]) for k=0:n]])
# Out:
# CairoSurface(Ptr{Void} @0x00007fe3d4d5ab90,512.0,518.0,#undef)

# %%
numtrials = 1_000_000 
2/(sum([hitline(needle(n)) for _=1:numtrials])/numtrials)
# Out:
# 3.1428652245105773

# %%
π
# Out:
# π = 3.1415926535897...

# %% [markdown]
# ## Bertrand's Paradox

# %%
# Chose the chord's midpoint from area measure on the disk
function randomchord1()
    x,y = 2*rand()-1, 2*rand()-1
    if x^2 + y^2 < 1
        θ = angle(x+im*y)
        ψ = acos(hypot(x,y))
        return [(cos(θ-ψ),sin(θ-ψ)),(cos(θ+ψ),sin(θ+ψ))]
    else
        return randomchord1()
    end
end

# Choose the chord's midpoint's polar coordinates
# from area measure on the rectangle [0,1] x [0,2π]
function randomchord2()
    r,θ = rand(), 2π*rand()
    x,y = r*cos(θ), r*sin(θ)
    if x^2 + y^2 < 1
        θ = angle(x+im*y)
        ψ = acos(hypot(x,y))
        return [(cos(θ-ψ),sin(θ-ψ)),(cos(θ+ψ),sin(θ+ψ))]
    else
        return randomchord2()
    end
end

# Choose the angles θ and φ of the endpoints of the chord
# from area measure on [0,2π] x [0,2π]
function randomchord3()
    θ,φ = 2π*rand(), 2π*rand()
    return [(cos(θ),sin(θ)),(cos(φ),sin(φ))]
end
# Out:
# randomchord3 (generic function with 1 method)

# %%
showgraphics([[Line(randomchord1()) for _=1:1000],[Circle((0,0),1)]])
# Out:
# CairoSurface(Ptr{Void} @0x00007fe3d4a75a10,512.0,512.0,#undef)

# %%
showgraphics([[Line(randomchord2()) for _=1:1000],[Circle((0,0),1)]])
# Out:
# CairoSurface(Ptr{Void} @0x00007fe3d4f8ec20,512.0,512.0,#undef)

# %%
showgraphics([[Line(randomchord3()) for _=1:1000],[Circle((0,0),1)]])
# Out:
# CairoSurface(Ptr{Void} @0x00007fe3d4f8fd80,512.0,512.0,#undef)

# %%
# Compute the total length of a Line object
function totallength(L::Line)
    c = L.coords
    len = 0.0
    for i in 1:size(c)[1]-1
        len += sqrt(sum((c[i,:] - c[i+1,:]).^2))
    end
    return len
end
# Out:
# totallength (generic function with 1 method)

# %%
rc1 = [totallength(Line(randomchord1())) for _=1:1_000_000]
sum(rc1 .> sqrt(3))/length(rc1)
# Out:
# 0.250447

# %%
rc2 = [totallength(Line(randomchord2())) for _=1:1_000_000]
sum(rc2 .> sqrt(3))/length(rc2)
# Out:
# 0.500411

# %%
rc3 = [totallength(Line(randomchord3())) for _=1:1_000_000]
sum(rc3 .> sqrt(3))/length(rc3)
# Out:
# 0.333857

# %%
B,H = hist([rand()+rand() for _=1:100_000],0:0.02:2)
# Out:
# (0.0:0.02:2.0,[30,53,110,151,168,199,290,302,335,401  …  350,313,330,267,237,187,136,111,68,16])

# %%
plot(x=B,y=H,Geom.bar)
# Out:
# Plot(...)
